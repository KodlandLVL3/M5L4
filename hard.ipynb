# %%
import matplotlib.pyplot as plt
import cv2

def show(image):
    # Отображение изображения с помощью matplotlib
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # Отключение осей координат
    plt.show()

# %%
import cv2 as cv


# Load two images
img1 = cv.imread('fon.jpg')
img2 = cv.imread('cat.png')
assert img1 is not None, "file could not be read, check with os.path.exists()"
assert img2 is not None, "file could not be read, check with os.path.exists()"
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols]
# Now create a mask of logo and create its inverse mask also
img2gray = cv.cvtColor(img2,cv.COLOR_BGR2GRAY)
ret, mask = cv.threshold(img2gray, 10, 255, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)
# Now black-out the area of logo in ROI
img1_bg = cv.bitwise_and(roi,roi,mask = mask_inv)
# Take only region of logo from logo image.
img2_fg = cv.bitwise_and(img2,img2,mask = mask)
# Put logo in ROI and modify the main image
dst = cv.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst
show(img1)

# %%
import cv2
import dlib


# Load the detector
detector = dlib.get_frontal_face_detector()

# read the image
img = cv2.imread("6.png")

# Convert image into grayscale
gray = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY)

# Use detector to find landmarks
faces = detector(gray)
for face in faces:
    x1 = face.left() # left point
    y1 = face.top() # top point
    x2 = face.right() # right point
    y2 = face.bottom() # bottom point
    # Draw a rectangle
    #cv2.rectangle(img=img, pt1=(x1, y1), pt2=(x2, y2), color=(0, 255, 0), thickness=4)

# show the image
show(img)

# %%
image = img
print("Высота:"+str(image.shape[0]))
print("Ширина:" + str(image.shape[1]))
print("Количество каналов:" + str(image.shape[2]))
# Out:
# Высота:852
# Ширина:1100
# Количество каналов:3

# %%
image = cv.imread('d.png')
print("Высота:"+str(image.shape[0]))
print("Ширина:" + str(image.shape[1]))
print("Количество каналов:" + str(image.shape[2]))
# Out:
# Высота:604
# Ширина:604
# Количество каналов:3

# %%
img2 = cv.imread('d.png')

new_width = y2-y1
new_height = x2-x1
img2 = cv2.resize(img2, (new_width, new_height))
show(img2)

# %%
y1 = int(y1-0.3*new_height)
y2 = int(y2-0.3*new_height)

# %%
y1, y2
# Out:
# (64, 599)

# %%
rows,cols,channels = img2.shape
roi = img[y1:y2, x1:x2 ]

# %%
show(roi)

# %%
img2gray = cv.cvtColor(img2,cv.COLOR_BGR2GRAY)
show(img2gray)

# %%
ret, mask = cv.threshold(img2gray, 10, 255, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)
show(mask_inv)

# %%
img1_bg = roi.copy()
img1_bg = cv.bitwise_and(img1_bg,img1_bg,mask = mask_inv)
show(img1_bg)

# %%
img2_fg = cv.bitwise_and(img2,img2,mask = mask)
show(img2_fg)

# %%
dst = cv.add(img1_bg,img2_fg)
img[y1:y2, x1:x2 ] = dst
show(img)

# %%
import cv2 as cv
y1 = int(y1-0.3*new_height)
y2 = int(y2-0.3*new_height)
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img[y1:y2, x1:x2 ]
# Now create a mask of logo and create its inverse mask also
img2gray = cv.cvtColor(img2,cv.COLOR_BGR2GRAY)
ret, mask = cv.threshold(img2gray, 10, 255, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)
# Now black-out the area of logo in ROI
img1_bg = roi.copy()
img1_bg = cv.bitwise_and(img1_bg,img1_bg,mask = mask_inv)
# Take only region of logo from logo image.
img2_fg = cv.bitwise_and(img2,img2,mask = mask)
# Put logo in ROI and modify the main image
dst = cv.add(img1_bg,img2_fg)
img[y1:y2, x1:x2 ] = dst
show(img)

# %%
import cv2
import dlib


# Load the detector
detector = dlib.get_frontal_face_detector()

# read the image
img = cv2.imread("6.png")

# Convert image into grayscale
gray = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY)

# Use detector to find landmarks
faces = detector(gray)
for face in faces:
    x1 = face.left() # left point
    y1 = face.top() # top point
    x2 = face.right() # right point
    y2 = face.bottom() # bottom point
    # Draw a rectangle
    cv2.rectangle(img=img, pt1=(x1, y1), pt2=(x2, y2), color=(0, 255, 0), thickness=4)

# show the image
show(img)
